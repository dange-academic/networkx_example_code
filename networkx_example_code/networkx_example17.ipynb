# %% [markdown]
# ### 《NetworkX编程实践基础》
# ##### 17课：计算图的邻接矩阵的谱和拉普拉斯矩阵的谱（特征值）

# %%
# !/usr/bin/python3
# -*- coding: utf-8 -*-
# Author ： 单哥的科研日常
# 示例程序所用库的版本：networkx==2.6.3, numpy==1.23.1

# %%
import networkx as nx
import numpy as np

# %%
# 生成包含n个节点，连边概率为p的ER随机图
n, p = 8, 0.5
G = nx.erdos_renyi_graph(n, p)
nx.draw(G, node_size=500, node_color='red', with_labels=True)

# %%
# 计算邻接矩阵的特征值
print(np.real(nx.adjacency_spectrum(G)))
# Out:
# [ 4.25628605  1.29570135 -2.45959493 -2.07701748  0.52525633  0.11403002
#  -1.13042233 -0.52423901]

# %%
# 计算拉普拉斯矩阵的特征值：第一个特征值通常为0
print(np.real(nx.laplacian_spectrum(G)))
# Out:
# [-2.11853105e-16  1.69884512e+00  2.95342694e+00  3.62790206e+00
#   4.33099764e+00  5.68149429e+00  6.50216927e+00  7.20516469e+00]
